# %% [markdown]
# <a href="https://colab.research.google.com/github/yamuna-code/AI-Assignment1/blob/main/SALARYvsCGPA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #25 NOVEMBER
# ---

# %%
#Yamuna495
import matplotlib.pyplot as plt

# %%
x_cgpa = [2,3,4,5]
y_salary = [20000,30000,40000,50000]

# %%
.plt.plot(x_cgpa,y_salary)
plt.xlabel("cgpa")
plt.ylabel("salary")
plt.title("cgpa vs salary")
plt.show()
